# %%
import parcels
import xmitgcm as xm
from datetime import timedelta, datetime
import os
import json

import random
import numpy as np
import time

import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Create velocity fields from MITgcm

# %%
variables = {"U": "UVEL", "V": "VVEL", "W": "WVEL"}
dimensions = {
    "U": {
        "lon": "XG",
        "lat": "YG",
        "depth": "Z",
        "time": "time",
    },
    "V": {
        "lon": "XG",
        "lat": "YG",
        "depth": "Z",
        "time": "time",
    },
    "W": {
        "lon": "XG",
        "lat": "YG",
        "depth": "Z",
        "time": "time",
    },
}
fieldset = parcels.FieldSet.from_mitgcm(
    filenames=['my_file.nc'], 
    variables=variables, 
    dimensions=dimensions, 
    allow_time_extrapolation=False,
    mesh='flat') # mesh='flat' if longitudes and latitudes are given in meters, rather than degrees

# %% [markdown]
# ## FTLE

# %%
ftle_type = 'backward'
first_date = datetime(2021, 9, 3, 0, 30, 0)

# %%
if ftle_type == 'forward':
    ftle_file = f'../TBarrier/TBarrier/2D/work_space/results/24h_forward_ftle_geneva/FTLE Geneva {first_date.strftime("%Y-%m-%d_%H-%M-%S")} - {(first_date + timedelta(days=1)).strftime("%Y-%m-%d_%H-%M-%S")}.csv'
elif ftle_type == 'backward':
    ftle_file = f'../TBarrier/TBarrier/2D/work_space/results/24.0h_backward_ftle_geneva/backward FTLE {first_date.strftime("%Y-%m-%d_%H-%M-%S")} - {(first_date - timedelta(days=1)).strftime("%Y-%m-%d_%H-%M-%S")}.csv'

# %%
df_ftle = pd.read_csv(ftle_file,header=None)

# %%
plt.figure(figsize=(15,7))
plt.pcolormesh(fieldset.U.grid.lon, fieldset.U.grid.lat, df_ftle)
plt.title(f'{ftle_type} FTLE {date_str}')
plt.xlabel("X [m]")
plt.ylabel("Y [m]")
plt.colorbar()
plt.savefig(f'./output/ftle_{ftle_type}_{first_date.strftime("%Y-%m-%d_%H-%M-%S")}')

# %% [markdown]
# ## Create particle set

# %% [markdown]
# Here we create particles randomly seeded within a defined circle.

# %%
def RandomPointInCircle(R,xc,yc):
    r = R*random.random()
    theta = 2*np.pi*random.random()
    
    return xc+r*np.cos(theta),yc+r*np.sin(theta)

# %%
def RandomPointInRectangle(xmin, xmax, ymin, ymax):
    return xmin+(xmax-xmin)*random.random(), ymin+(ymax-ymin)*random.random()

# %%
def RandomPointWithNonNullFtleValues(df_ftle, fieldset):
    # Get indices of values that are neither NaN nor zero
    valid_indices = list(zip(*np.where((abs(df_ftle) > 1e-6) & df_ftle.notna())))
    random_indices = valid_indices[np.random.choice(len(valid_indices))]

    return fieldset.U.grid.lon[random_indices[1]], fieldset.U.grid.lat[random_indices[0]]

# %%
n_part = 1000 # number of particles
depth_min = 4 # minimum release depth
depth_max = 10 # maximum release depth
(x_c,y_c) = (45000, 18000) # center of seeding point in MITgcm coordinates
r_seeding = 2000 # the radius around the center in m

zi_particles = np.array([-random.uniform(depth_min, depth_max) for i in range(n_part)])
xi_particles = x_c*np.ones(n_part)
yi_particles = y_c*np.ones(n_part)

init_time_particles = (np.datetime64('2021-09-03') - np.datetime64('2021-07-26'))/ np.timedelta64(1, 's') # seconds since ref_date
timei_particles = init_time_particles*np.ones(n_part)

for i in range(n_part):
    (xd,yd) = RandomPointInCircle(r_seeding,x_c,y_c)
    xi_particles[i] = xd
    yi_particles[i] = yd

# %% [markdown]
# n_part = 10000 # number of particles
# depth_min = 4 # minimum release depth
# depth_max = 10 # maximum release depth
#
# zi_particles = np.array([-random.uniform(depth_min, depth_max) for i in range(n_part)])
# xi_particles = np.ones(n_part)
# yi_particles = np.ones(n_part)
#
# init_time_particles = (np.datetime64('2021-09-02') - np.datetime64('2021-07-26'))/ np.timedelta64(1, 's') # seconds since ref_date
# timei_particles = init_time_particles*np.ones(n_part)
#
# for i in range(n_part):
#     (xd,yd) = RandomPointWithNonNullFtleValues(df_ftle, fieldset)
#     xi_particles[i] = xd
#     yi_particles[i] = yd

# %%
pset = parcels.ParticleSet.from_list(
    fieldset=fieldset,  # the fields on which the particles are advected
    pclass=parcels.JITParticle,  # the type of particles (JITParticle or ScipyParticle)
    lon=xi_particles,  # a vector of release longitudes
    lat=yi_particles,  # a vector of release latitudes
    depth=zi_particles,
    time=timei_particles
)

# %%
plt.figure(figsize=(15,7))
plt.pcolormesh(fieldset.U.grid.lon, fieldset.U.grid.lat, df_ftle)
plt.xlabel("X [m]")
plt.ylabel("Y [m]")
plt.colorbar()

plt.scatter(pset.lon, pset.lat, s=3, c='r')
#plt.xlim(left=35000, right=50000)
#plt.ylim(bottom=15000)
plt.show()

# %% [markdown]
# plt.pcolormesh(fieldset.U.grid.lon, fieldset.U.grid.lat, fieldset.U.data[0, 0, :-1, :-1])
# plt.xlabel("X [m]")
# plt.ylabel("Y [m]")
# plt.colorbar()
#
# plt.plot(pset.lon, pset.lat, "ko")
# plt.xlim(left=35000, right=50000)
# plt.ylim(bottom=15000)
# plt.show()

# %% [markdown]
# ## Set output parameters

# %%
output_file = pset.ParticleFile(
    name="eddy_analysis.zarr",  # the file name
    outputdt=timedelta(hours=1),  # the time step of the outputs
)

# %% [markdown]
# ## Run simulation

# %%
start_clock = time.time()
pset.execute(
    parcels.AdvectionRK4,  # the kernel (which defines how particles move)
    runtime=timedelta(days=2),  # the total length of the run
    dt=timedelta(minutes=60),  # the timestep of the kernel
    output_file=output_file,
)
end_clock = time.time()
print(f'Done. Operation took {end_clock - start_clock}s.')
# Out:
# INFO: Output files are stored in eddy_analysis.zarr.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 172800.0/172800.0 [05:01<00:00, 572.87it/s]
# Done. Operation took 303.42479944229126s.
